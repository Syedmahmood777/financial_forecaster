# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
daily_pd=pd.read_csv(r'C:\Users\WELCOME\Desktop\financial_forecaster\daily_transactions.csv')
mon_pd=pd.read_csv(r'C:\Users\WELCOME\Desktop\financial_forecaster\monthly_transactions.csv')
alltr_df=pd.read_csv(r'C:\Users\WELCOME\Desktop\financial_forecaster\transactions_upi.csv')

# %%
a4_dims = (30, 20)
fig, ax = plt.subplots(figsize=a4_dims)
sns.color_palette("crest", as_cmap=True)
sns.lineplot(mon_pd['Date'],mon_pd['Withdrawls'],color='#F85888',ax=ax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 4
#       2 fig, ax = plt.subplots(figsize=a4_dims)
#       3 sns.color_palette("crest", as_cmap=True)
# ----> 4 sns.lineplot(mon_pd['Date'],mon_pd['Withdrawls'],color='#F85888',ax=ax)
#
# TypeError: lineplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
a4_dims = (10, 8)
fig, ax = plt.subplots(figsize=a4_dims)

sns.boxplot(daily_pd['Withdrawls'])
# Out:
# <Axes: >

# %%
a4_dims = (12, 8)
fig, ax = plt.subplots(figsize=a4_dims)
sns.boxplot(mon_pd['Withdrawls'])
# Out:
# <Axes: >
